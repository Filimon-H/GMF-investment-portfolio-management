# %%
# Standard imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os
sys.path.append(os.path.abspath('../src'))

# Our custom module
from data_loader import fetch_asset_data
from preprocessing import inspect_asset, clean_missing_values, normalize_close_column

# Plot settings
plt.style.use("seaborn-v0_8-darkgrid")
sns.set_context("notebook")

# %%
# Define tickers and dates
tickers = ['TSLA', 'SPY', 'BND']
start_date = '2015-07-01'
end_date = '2025-07-31'

# Fetch data safely
data_dict, adj_close = fetch_asset_data(tickers, start_date, end_date)

# Save to CSV
import os
os.makedirs("../data/raw", exist_ok=True)

for ticker in tickers:
    if ticker in data_dict:
        data_dict[ticker].to_csv(f"../data/raw/{ticker}.csv")

adj_close.to_csv("../data/raw/adj_close.csv")
# Out:
# c:\Users\filimon.hailemariam\Downloads\Week 11\GMF-investment-portfolio-management\src\data_loader.py:18: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date, progress=False)
# c:\Users\filimon.hailemariam\Downloads\Week 11\GMF-investment-portfolio-management\src\data_loader.py:18: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date, progress=False)
# c:\Users\filimon.hailemariam\Downloads\Week 11\GMF-investment-portfolio-management\src\data_loader.py:18: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date, progress=False)

# %%
# Reload individual CSVs
tsla_df = pd.read_csv("../data/raw/TSLA.csv", parse_dates=['Date'], index_col='Date')
spy_df = pd.read_csv("../data/raw/SPY.csv", parse_dates=['Date'], index_col='Date')
bnd_df = pd.read_csv("../data/raw/BND.csv", parse_dates=['Date'], index_col='Date')

# Preview TSLA
tsla_df.head()
# Out:
#                 Close       High        Low       Open     Volume Ticker
# Date
# 2015-07-01  17.943333  18.174667  17.856667  18.073999   31518000   TSLA
# 2015-07-02  18.667999  18.830000  18.220667  18.680000  107458500   TSLA
# 2015-07-06  18.648001  18.779333  18.420000  18.591999   61828500   TSLA
# 2015-07-07  17.858667  18.346666  17.384666  18.333332   91576500   TSLA
# 2015-07-08  16.997334  17.386667  16.954000  17.288000   93316500   TSLA

# %%
inspect_asset(tsla_df, "TSLA")
inspect_asset(spy_df, "SPY")
inspect_asset(bnd_df, "BND")
# Out:
# 📊 TSLA Summary
# Shape: (2535, 6)
# Missing values:
#  Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# Ticker    0
# dtype: int64
# Data types:
#  Close     float64
# High      float64
# Low       float64
# Open      float64
# Volume      int64
# Ticker     object
# dtype: object
# Duplicated rows: 0
# Statistical Summary:
#              Close         High          Low         Open        Volume
# count  2535.000000  2535.000000  2535.000000  2535.000000  2.535000e+03
# mean    131.963002   134.960429   128.837831   132.000600  1.141789e+08
# std     120.914904   123.783736   117.996631   121.034152  7.332146e+07
# min       9.578000    10.331333     9.403333     9.488000  1.062000e+07
# 25%      18.967667    19.279667    18.575334    18.901000  6.908220e+07
# 50%      94.571335    97.666664    91.734001    94.400665  9.537450e+07
# 75%     236.761665   240.881668   232.170006   235.851669  1.322551e+08
# ...

# %%
# Use interpolation for small gaps
tsla_df_clean = clean_missing_values(tsla_df, method='interpolate')
spy_df_clean = clean_missing_values(spy_df, method='interpolate')
bnd_df_clean = clean_missing_values(bnd_df, method='interpolate')
# Out:
# c:\Users\filimon.hailemariam\Downloads\Week 11\GMF-investment-portfolio-management\src\preprocessing.py:22: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   return df.interpolate(method='linear')
# c:\Users\filimon.hailemariam\Downloads\Week 11\GMF-investment-portfolio-management\src\preprocessing.py:22: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   return df.interpolate(method='linear')
# c:\Users\filimon.hailemariam\Downloads\Week 11\GMF-investment-portfolio-management\src\preprocessing.py:22: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   return df.interpolate(method='linear')
